-- %% [markdown]
-- # [UP2_8ZAYCEV]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [UP2_8ZAYCEV]    Script Date: 22.01.2025 17:07:45 ******/
CREATE DATABASE [UP2_8ZAYCEV]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'UP2_8ZAYCEV', FILENAME = N'E:\SQL\MSSQL15.SQLEXPRESS\MSSQL\DATA\UP2_8ZAYCEV.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'UP2_8ZAYCEV_log', FILENAME = N'E:\SQL\MSSQL15.SQLEXPRESS\MSSQL\DATA\UP2_8ZAYCEV_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [UP2_8ZAYCEV] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [UP2_8ZAYCEV].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ARITHABORT OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET  DISABLE_BROKER 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET  MULTI_USER 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [UP2_8ZAYCEV] SET DB_CHAINING OFF 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [UP2_8ZAYCEV] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [UP2_8ZAYCEV] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Ads]

-- %%
USE [UP2_8ZAYCEV]
GO

-- %%
/****** Object:  Table [dbo].[Ads]    Script Date: 22.01.2025 17:07:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ads](
	[AdID] [int] IDENTITY(1,1) NOT NULL,
	[PublicationDate] [date] NOT NULL,
	[City] [varchar](50) NOT NULL,
	[Address] [varchar](255) NOT NULL,
	[UserID] [int] NOT NULL,
	[CategoryID] [int] NOT NULL,
	[TypeID] [int] NOT NULL,
	[StatusID] [int] NOT NULL,
	[Title] [varchar](100) NOT NULL,
	[Description] [text] NOT NULL,
	[Price] [int] NOT NULL,
	[photo] [varchar](max) NULL,
 CONSTRAINT [PK_Ads] PRIMARY KEY CLUSTERED 
(
	[AdID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AdStatuses]

-- %%
/****** Object:  Table [dbo].[AdStatuses]    Script Date: 22.01.2025 17:07:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AdStatuses](
	[StatusID] [int] IDENTITY(1,1) NOT NULL,
	[StatusName] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[StatusID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[StatusName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 22.01.2025 17:07:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[CategoryID] [int] IDENTITY(1,1) NOT NULL,
	[CategoryName] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[CategoryID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[CategoryName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Types]

-- %%
/****** Object:  Table [dbo].[Types]    Script Date: 22.01.2025 17:07:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Types](
	[TypeID] [int] IDENTITY(1,1) NOT NULL,
	[TypeName] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[TypeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[TypeName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 22.01.2025 17:07:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserID] [int] IDENTITY(1,1) NOT NULL,
	[Login] [varchar](50) NOT NULL,
	[Password] [varchar](255) NOT NULL,
	[Profit] [int] NULL,
	[Name] [varchar](50) NOT NULL,
	[PhoneNumber] [varchar](15) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Login] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Users__Profit__25869641]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((0)) FOR [Profit]
GO

-- %% [markdown]
-- # [FK__Ads__CategoryID__31EC6D26]

-- %%
ALTER TABLE [dbo].[Ads]  WITH CHECK ADD FOREIGN KEY([CategoryID])
REFERENCES [dbo].[Categories] ([CategoryID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Ads__StatusID__33D4B598]

-- %%
ALTER TABLE [dbo].[Ads]  WITH CHECK ADD FOREIGN KEY([StatusID])
REFERENCES [dbo].[AdStatuses] ([StatusID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Ads__TypeID__32E0915F]

-- %%
ALTER TABLE [dbo].[Ads]  WITH CHECK ADD FOREIGN KEY([TypeID])
REFERENCES [dbo].[Types] ([TypeID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__Ads__UserID__30F848ED]

-- %%
ALTER TABLE [dbo].[Ads]  WITH CHECK ADD FOREIGN KEY([UserID])
REFERENCES [dbo].[Users] ([UserID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [UP2_8ZAYCEV]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [UP2_8ZAYCEV] SET  READ_WRITE 
GO
